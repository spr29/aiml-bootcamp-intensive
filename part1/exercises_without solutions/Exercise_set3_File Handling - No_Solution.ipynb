# %% [markdown]
# <div class="alert" style="background-color:#fff; color:white; padding:0px 10px; border-radius:5px;"><h1 style='margin:15px 15px; color:#006a79; font-size:40px; text-align:center'>Exercises - Set 3: File Handling</h1>
# </div>
#
# __<p style='text-align:center'>Copyright (©) Machine Learning Plus. All Rights Reserved.</p>__

# %% [markdown]
# ### Exercise 1: CSV Data Aggregation
#
# **Description:**
# You have a CSV file (`sales_data.csv`) containing sales data with the following columns: `Date`, `Product`, `Quantity`, `Price`. Your task is to read this file and calculate the total sales amount for each product.
#
# **Example Input (`sales_data.csv`):**
# ```
# Date,Product,Quantity,Price
# 2024-10-01,Widget A,2,20.00
# 2024-10-02,Widget B,1,15.00
# 2024-10-02,Widget A,1,20.00
# 2024-10-03,Widget C,3,10.00
# ```
#
# **Expected Output:**
# ```
# Total sales amount for each product:
# Widget A: 60.00
# Widget B: 15.00
# Widget C: 30.00
# ```

# %%
# Write your solution here..

# %% [markdown]
# ---
#
# ### Exercise 2: Log File Analysis
#
# **Description:**
# You have a log file (`server_log.txt`) containing server access logs in the following format: `timestamp user_id action`. Your task is to read this file and count the number of times each user performed an action.
#
# **Example Input (`server_log.txt`):**
# ```
# 2024-10-01 10:00 user1 login
# 2024-10-01 10:05 user2 logout
# 2024-10-01 10:10 user1 view
# 2024-10-01 10:15 user1 logout
# 2024-10-01 10:20 user2 login
# ```
#
# **Expected Output:**
# ```
# User action counts:
# user1: 3
# user2: 2
# ```

# %%
# Write your solution here..

# %% [markdown]
# ---
#
# ### Exercise 3: JSON Data Transformation
#
# **Description:**
# You have a JSON file (`user_data.json`) containing user information with fields: `id`, `name`, and `email`. Your task is to read this file, transform the data into a new format that includes only the user's name and email, and write this new data to a new JSON file (`transformed_user_data.json`).
#
# **Example Input (`user_data.json`):**
# ```json
# [
#     {"id": 1, "name": "Alice", "email": "alice@example.com"},
#     {"id": 2, "name": "Bob", "email": "bob@example.com"}
# ]
# ```
#
# **Expected Output (`transformed_user_data.json`):**
# ```json
# [
#     {"name": "Alice", "email": "alice@example.com"},
#     {"name": "Bob", "email": "bob@example.com"}
# ]
# ```
